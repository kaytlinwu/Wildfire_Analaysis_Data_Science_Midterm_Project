# %% [markdown]
# # Build a multinomial logistic model

# %%
#import libraries required
import statsmodels.api as sm
import pandas as pd
import numpy as np

# %%
#load df into notebook
df = pd.read_csv('../Data/forest_fire_clean.csv')
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area  \
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0
#
#    month_num  day_num  area_squared_km  fire_spread
# 0          3        4              0.0            0
# 1         10        1              0.0            0
# 2         10        5              0.0            0
# 3          3        4              0.0            0
# 4          3        6              0.0            0

# %%
#drop redundant columns
df_final = df.drop(columns= ['month','day','area','area_squared_km'], axis=1)

# %%
#Drop duplicate values
df_final = df_drop.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Drop duplicate values
# ----> 2 df_final = df_drop.drop_duplicates()
#
# NameError: name 'df_drop' is not defined

# %%
#Drop all null values (cannot be used in the analysis)
df_final = df_final.dropna(how='any',axis=0)

# %%
#Verify that nf has no null values
df_final.isna().sum()
# Out:
# X              0
# Y              0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# temp           0
# RH             0
# wind           0
# rain           0
# month_num      0
# day_num        0
# fire_spread    0
# dtype: int64

# %%
df_final.shape
#df.shape
# Out:
# (512, 13)

# %%
df_final.head()
# Out:
#    X  Y  FFMC   DMC     DC  ISI  temp  RH  wind  rain  month_num  day_num  \
# 0  7  5  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0          3        4
# 1  7  4  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0         10        1
# 2  7  4  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0         10        5
# 3  8  6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2          3        4
# 4  8  6  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0          3        6
#
#    fire_spread
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(data=df_final)
plt.show()

# %%
#Finding the correlation 
df_final.corr(numeric_only = True)
# Out:
#                     X         Y      FFMC       DMC        DC       ISI  \
# X            1.000000  0.543747 -0.021824 -0.048463 -0.086293 -0.015867
# Y            0.543747  1.000000 -0.045686  0.008102 -0.099368 -0.020476
# FFMC        -0.021824 -0.045686  1.000000  0.384121  0.335555  0.582868
# DMC         -0.048463  0.008102  0.384121  1.000000  0.682472  0.347262
# DC          -0.086293 -0.099368  0.335555  0.682472  1.000000  0.288681
# ISI         -0.015867 -0.020476  0.582868  0.347262  0.288681  1.000000
# temp        -0.051837 -0.023702  0.431380  0.469836  0.499620  0.434592
# RH           0.083881  0.062581 -0.300928  0.071705 -0.044212 -0.149293
# wind         0.020357 -0.019409 -0.029576 -0.105002 -0.202667  0.113819
# rain         0.065385  0.033280  0.056926  0.074751  0.035557  0.077653
# month_num   -0.065755 -0.065726  0.294521  0.464286  0.868115  0.223406
# day_num     -0.025182 -0.006050 -0.043413  0.064707  0.007736  0.007131
# fire_spread  0.060252  0.048657  0.077345  0.067557  0.097867  0.057703
#
#                  temp        RH      wind      rain  month_num   day_num  \
# X           -0.051837  0.083881  0.020357  0.065385  -0.065755 -0.025182
# Y           -0.023702  0.062581 -0.019409  0.033280  -0.065726 -0.006050
# FFMC         0.431380 -0.300928 -0.029576  0.056926   0.294521 -0.043413
# DMC          0.469836  0.071705 -0.105002  0.074751   0.464286  0.064707
# DC           0.499620 -0.044212 -0.202667  0.035557   0.868115  0.007736
# ISI          0.434592 -0.149293  0.113819  0.077653   0.223406  0.007131
# temp         1.000000 -0.528723 -0.227857  0.069588   0.369799  0.051904
# RH          -0.528723  1.000000  0.071450  0.099613  -0.100244  0.095444
# wind        -0.227857  0.071450  1.000000  0.061523  -0.084853  0.029545
# rain         0.069588  0.099613  0.061523  1.000000   0.013098 -0.048099
# month_num    0.369799 -0.100244 -0.084853  0.013098   1.000000 -0.046238
# day_num      0.051904  0.095444  0.029545 -0.048099  -0.046238  1.000000
# fire_spread  0.083019 -0.038817  0.049076  0.023196   0.135430 -0.047650
#
#              fire_spread
# X               0.060252
# Y               0.048657
# FFMC            0.077345
# DMC             0.067557
# DC              0.097867
# ISI             0.057703
# temp            0.083019
# RH             -0.038817
# wind            0.049076
# rain            0.023196
# month_num       0.135430
# day_num        -0.047650
# fire_spread     1.000000

# %% [markdown]
# # Set variables for analysis:
#
# Dependent variable(y) = fire_spread <br />
# Independent variables(x) = X , Y, FFMC, DMC, DC, ISI, temp, RH, wind, rain,month_num, day_num <br />

# %% [markdown]
# ## Bins Created in EDA
#
# fire_spread 1 = minimal spread <br>
# fire_spread 2 = moderate spread <br>
# fire_spread 3 = large spread <br>

# %%
import math

df_final['fire_spread'] = df_final['fire_spread'] +1

# %%
df_final['fire_spread'].value_counts()
# Out:
# 2    263
# 1    244
# 3      5
# Name: fire_spread, dtype: int64

# %%
x = df_final[['X','Y','FFMC','DMC','DC','ISI','temp','RH','wind','rain','month_num','day_num']] #set x variable
y = df_final['fire_spread'] #set y variable

model = sm.MNLogit(y, x) #set as float values

results = model.fit() #fit the model
print(results.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.720392
#          Iterations: 35
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            fire_spread   No. Observations:                  512
# Model:                        MNLogit   Df Residuals:                      488
# Method:                           MLE   Df Model:                           22
# Date:                Wed, 27 Sep 2023   Pseudo R-squ.:                 0.02729
# Time:                        22:01:41   Log-Likelihood:                -368.84
# converged:                      False   LL-Null:                       -379.19
# Covariance Type:            nonrobust   LLR p-value:                    0.5395
# =================================================================================
# fire_spread=2       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# X                 0.0386      0.047      0.828      0.408      -0.053       0.130
# Y                 0.0581      0.088      0.661      0.509      -0.114       0.230
# FFMC             -0.0175      0.009     -2.010      0.044      -0.035      -0.000
# DMC               0.0009      0.002      0.429      0.668      -0.003       0.005
# DC               -0.0007      0.001     -0.620      0.535      -0.003       0.001
# ISI               0.0155      0.026      0.586      0.558      -0.036       0.067
# temp              0.0091      0.025      0.365      0.715      -0.040       0.058
# RH               -0.0039      0.007     -0.575      0.565      -0.017       0.009
# wind              0.0683      0.055      1.253      0.210      -0.039       0.175
# rain              0.1261      0.356      0.354      0.724      -0.573       0.825
# month_num         0.1635      0.096      1.697      0.090      -0.025       0.352
# day_num          -0.0419      0.045     -0.941      0.347      -0.129       0.045
# ---------------------------------------------------------------------------------
# fire_spread=3       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# X                 0.2160      0.229      0.944      0.345      -0.232       0.664
# Y                -0.5973      0.468     -1.276      0.202      -1.515       0.320
# FFMC             -0.0815      0.060     -1.348      0.178      -0.200       0.037
# DMC               0.0120      0.010      1.237      0.216      -0.007       0.031
# DC               -0.0043      0.004     -1.001      0.317      -0.013       0.004
# ISI              -0.0262      0.143     -0.184      0.854      -0.306       0.253
# temp              0.1333      0.125      1.070      0.285      -0.111       0.378
# RH               -0.0049      0.039     -0.126      0.900      -0.081       0.072
# wind             -0.0479      0.327     -0.146      0.884      -0.689       0.594
# rain            -62.1376   5.02e+04     -0.001      0.999   -9.84e+04    9.83e+04
# month_num         0.5414      0.456      1.188      0.235      -0.352       1.435
# day_num          -0.1472      0.233     -0.632      0.527      -0.604       0.309
# =================================================================================
# C:\Users\UltimateKayCorp\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
